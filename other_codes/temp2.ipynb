# %%
import pandas as pd
from sqlalchemy import create_engine, text


DATABASE_URL = "mysql://sortinghatadmin:Sortinghat#Middle123@rds-middle-ilt-app.c61momvubcsz.us-east-1.rds.amazonaws.com:3306/dbiltappuat"

server_url = "UAT"  # "PROD"
DATABASE_URLS_DICT = {
    "PROD": "mysql://sortinghatadmin:Sortinghat#Middle123@rds-middle-ilt-app.c61momvubcsz.us-east-1.rds.amazonaws.com:3306/dbiltapp",
    "UAT": "mysql://sortinghatadmin:Sortinghat#Middle123@rds-middle-ilt-app.c61momvubcsz.us-east-1.rds.amazonaws.com:3306/dbiltappuat",
    "sqllite": "sqlite:///ilt_db.db"
}
DATABASE_URL = DATABASE_URLS_DICT.get(server_url)
DATABASE_URL2 = DATABASE_URLS_DICT.get("sqllite")

conn = create_engine(DATABASE_URL).connect()
conn2 = create_engine(DATABASE_URL2).connect()

# %%
df = pd.read_sql('SELECT * FROM INFORMATION_SCHEMA.COLUMNS;', conn)
df.head()
# Out:
#   TABLE_CATALOG TABLE_SCHEMA                    TABLE_NAME    COLUMN_NAME  \
# 0           def     dbiltapp  Ilt_issue_priorities_mapping             id
# 1           def     dbiltapp  Ilt_issue_priorities_mapping       issue_id
# 2           def     dbiltapp  Ilt_issue_priorities_mapping  priorities_id
# 3           def     dbiltapp            Ilt_meeting_maping             id
# 4           def     dbiltapp            Ilt_meeting_maping         ilt_id
#
#    ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE DATA_TYPE  \
# 0                 1           None          NO       int
# 1                 2           None          NO       int
# 2                 3           None          NO       int
# 3                 1           None          NO       int
# 4                 2           None          NO       int
#
#    CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  DATETIME_PRECISION  \
# 0                       NaN                     NaN  ...                 NaN
# 1                       NaN                     NaN  ...                 NaN
# 2                       NaN                     NaN  ...                 NaN
# 3                       NaN                     NaN  ...                 NaN
# 4                       NaN                     NaN  ...                 NaN
#
#    CHARACTER_SET_NAME  COLLATION_NAME COLUMN_TYPE COLUMN_KEY           EXTRA  \
# 0                None            None         int        PRI  auto_increment
# 1                None            None         int        MUL
# 2                None            None         int        MUL
# 3                None            None         int        PRI  auto_increment
# 4                None            None         int        MUL
#
#                         PRIVILEGES COLUMN_COMMENT GENERATION_EXPRESSION SRS_ID
# 0  select,insert,update,references                                        None
# 1  select,insert,update,references                                        None
# 2  select,insert,update,references                                        None
# 3  select,insert,update,references                                        None
# 4  select,insert,update,references                                        None
#
# [5 rows x 22 columns]

# %%
instance = "dbiltappuat"
list_of_table_name = df[df["TABLE_SCHEMA"] == instance]["TABLE_NAME"].unique()
list_of_table_name
# Out:
# array(['Ilt_end_meeting_member_rocks', 'Ilt_end_meeting_rocks',
#        'Ilt_issue_priorities_mapping', 'Ilt_meeting_maping',
#        'Ilt_meeting_rocks_maping', 'Ilt_meeting_whiteboard',
#        'Ilt_meetings', 'Ilt_members_maping', 'Ilt_priorities',
#        'Ilt_rocks', 'Ilt_to_do_mapping', 'Ilt_to_do_task',
#        'Ilt_user_rocks_mapping', 'Ilt_whiteboard', 'Ilts',
#        'Rocks_member_mapping', 'districts', 'districts_member_mapping',
#        'ilt_meeting_response_mapping', 'issue', 'meeting_issue_mapping',
#        'meeting_response', 'meeting_updates', 'roles', 'schools', 'users'],
#       dtype=object)

# %%
for tname in list_of_table_name:
    df = pd.read_sql_table(tname, conn)
    df.to_sql(tname, conn2, if_exists='replace')

# %%
df = pd.read_sql_table('users', conn)
df
# Out:
#     id          fname        lname                        email        number  \
# 0    1       ashutosh       tiwari                 as@gmail.com  9.098115e+11
# 1    2          AS_PR          rob                rob@gmail.com           NaN
# 2    3         Steven     Cantrell          steve@middle.design  1.212100e+04
# 3    4      Katherine      Wallace      katherine@middle.design           NaN
# 4    5         Alicia         Yang            ayang@kitamba.com           NaN
# 5    6        William    McPherson       wmcpherson@kitamba.com           NaN
# 6    7          Keanu      McDonou       kmcdonough@kitamba.com           NaN
# 7    8  Vishnuvardhan     Tirumala         vishnu@middle.design           NaN
# 8    9    Trinadhbabu  Singaladevi       trinadh@sortinghat.dev           NaN
# 9   10          Tuhin       Mondal  tuhin.mondal@sortinghat.dev           NaN
# 10  11           somu        reddy    somu.reddy@sortinghat.dev  2.147484e+09
# 11  12         as_mem        robin              robin@gmail.com           NaN
# 12  13          AS_PL       Mathew             mathew@gmail.com           NaN
# 13  14         AS_FAC         John               john@gmail.com           NaN
# 14  15         AS_FAC         Luke               luke@gmail.com           NaN
# 15  16          Harry       Potter              harry@gmail.com           NaN
# 16  17            Ron       Weasly                ron@gmail.com           NaN
# 17  18         AS_PR/     Rich_2Di               rich@gmail.com           NaN
# 18  19       rich_mem         ract               ract@gmail.com           NaN
# 19  20       rich_fac        stalk              stalk@gmail.com  1.100000e+01
# 20  21       rich_mem       ramshy             ramshy@gmail.com           NaN
# 21  22       rich_mem     tigerian           tigerian@gmail.com           NaN
# 22  23       rich_fac         neon               neon@gmail.com           NaN
# 23  24       rich_mem         fury               fury@gmail.com           NaN
# 24  25          AS_PR  randeep_3di            randeep@gmail.com           NaN
# 25  26    randeep_fac      babylon            babylon@gmail.com           NaN
# 26  27    randeep_fac     babylon2           babylon2@gmail.com           NaN
# 27  28    randeep_fac     babylon3           babylon3@gmail.com           NaN
# 28  29         bb_mem         jami               jami@gmail.com           NaN
# 29  30         bb_mem       rancho             rancho@gmail.com           NaN
# 30  31      Katherine      Wallace          katherine@gmail.com           NaN
# 31  32      Katherine      Wallace      wallacesk@sbcglobal.net           NaN
# 32  33      Katherine      Wallace      katherinewallace2@gmail           NaN
# 33  34          Steve     Cantrell            smcantrell@me.com           NaN
# 34  35          Steve     Cantrell            steve10@gmail.com           NaN
# 35  36      Katherine      Wallace  katherinewallace2@gmail.com           NaN
#
#                                              password  is_active  role_id  \
# 0   $2b$12$sh8fbakZAfS15TrhG8MC8.voisKQSfhSBzwzzvY...          1        4
# 1   $2b$12$gEYtHk4AfnLyyppb6fZerel8XN7Iw0brRJ9PjPG...          1        3
# 31  $2b$12$/sZjypv3aNPKUEGvoI8sUeYOntLr4BwXaR7V6Ab...          1        2
# 32  $2b$12$WBfA9jp.Ztz/49OvnFnPfuRPiStvehkXAACMWW....          1        2
# 33  $2b$12$Pae80TdRh5cnFteWM15u..hcEc/lXQOMhb7w0FW...          1        1
# 34  $2b$12$QrXtJQLp5x/aot5063RkUe3ZqBnY6tMf7Z8Sd5T...          0        1
# 35  $2b$12$o9Pg9tYIQJWSsbo8NkKsmuNY8ifZSkvuwHAGoq1...          1        2
#
#     parent_user_id                       salt_key
# 0                1  $2b$12$sh8fbakZAfS15TrhG8MC8.
# 1                1  $2b$12$gEYtHk4AfnLyyppb6fZere
# 2                1  $2b$12$Ju13JbnWThJZewiWK/D1Qe
# 3                1  $2b$12$tdFqI1r0zWmtqJIOBS/YXu
# 4                3  $2b$12$W1ZFESssAHz4sJwON.3.8u
# 5                0  $2b$12$IPNxWavjd4IgNokWvWhQ3O
# 6                6  $2b$12$1ZoKFji7t14X1m8t9MGlJO
# 7                0  $2b$12$P5mYtSR6VB3gZ.L2u0aEAe
# 8                0  $2b$12$Ryn.sF9IUr6k2NEGY1cyz.
# 9                1  $2b$12$.FuQfnEEH2yMhhJ9GAhLPe
# 10              11  $2b$12$0jFgxoORF5LmRanQebK5Ru
# 11               1  $2b$12$h3O3Tf9xwPIEXfZA4YqfLO
# 12               1  $2b$12$h201liKMWG/gKOTG6DtZ5u
# 13              13  $2b$12$8NDC..OvN4..RGLYLC.w4u
# 14              13  $2b$12$Qf3d5DTiv2rvyvi1MLoMLu
# 15              14  $2b$12$8C1/MU/h6ep6sRbzXfU/qe
# 16              14  $2b$12$nEyxPZeFEg9ViSbOKWfdZ.
# 17               1  $2b$12$nM8BB2kSV/u1rd4lr1cjge
# 18              18  $2b$12$R3is/Lt663PLZNPceLjguO
# 19               1  $2b$12$4I5AXDCDrchWiFmBnE3eQ.
# 20              18  $2b$12$0wmnvdRNZp.bU4Bk4ZA9n.
# 21              18  $2b$12$/./9tZZRb92P0PGrxg4vOu
# 22              18  $2b$12$8F4hSaUcFhxLKBXL6UFINe
# 23              18  $2b$12$O/00wRaz5LqWd/3upX5FJO
# 24               1  $2b$12$RNYuqo9od6Vt.mU6axHNqe
# 25              25  $2b$12$E6nAuCi6WdUvPP0idfzjKO
# 26              25  $2b$12$hw3wPPzy6WIwtdoxu/ml8.
# 27               1  $2b$12$z9j/fTBvDYKQ.z.bfhFwLe
# 28              26  $2b$12$ZfHXgrAmjwcV6VS5SBpe8.
# 29              26  $2b$12$7AQ593rI1SBKCiiYy52c0u
# 30               1  $2b$12$PSnSpUteKePrSMEGW8QFe.
# 31               1  $2b$12$/sZjypv3aNPKUEGvoI8sUe
# 32               4  $2b$12$WBfA9jp.Ztz/49OvnFnPfu
# 33              33  $2b$12$Pae80TdRh5cnFteWM15u..
# 34               4  $2b$12$QrXtJQLp5x/aot5063RkUe
# 35               4  $2b$12$o9Pg9tYIQJWSsbo8NkKsmu
